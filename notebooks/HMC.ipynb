# %%
import pandas as pd
import numpy as np
import os
import inspect
from datetime import datetime
from timeit import default_timer as timer
from matplotlib import pyplot as plt
import gc
from dataclasses import dataclass
from pathlib import Path
import pickle
from sklearn.cluster import KMeans
import sys
import threading
import time
import psutil
import scipy
import scipy.spatial

# %%
## Global Settings & Variables
# System path
cwd = Path.cwd()
src_path = cwd.parents[2]

# Column in the data frame that is used to determine the identity of a dataset
identifier_column = "FileName"

# Map part that is used in calculations
lon_min = -122.50
lon_max = -122.35
lat_min = 37.60
lat_max = 37.85

# Amount of grid cells used. Default amount (8 x 8) is based upon Dr. Maouche's descriptions and depictions
num_lon_bins = 8
num_lat_bins = 8

# Timer
start_timer = timer()
func_timer = 0

## Memory monitoring
# Global variable to hold memory usage
# Enable / disable memory output in console
memory_monitor_output = False
current_memory_usage = 0
memory_threshold = 85
memory_highest_value = 0
stop_event = threading.Event()


date_time_now = datetime.now()
date_time_now_str = date_time_now.strftime("%H:%M:%S")
print(f"Starting execution at: {date_time_now_str}")
# Out:
# Starting execution at: 12:15:36

# %%
## Load cabspotting sets from txt files
files_path = Path("Daten/cabspottingdata - Copy")
source_files_path =  os.path.join(src_path, files_path)

all_files = os.listdir(source_files_path)

text_files = [file for file in all_files if file.endswith('.txt')]

select_files = text_files 

# Global variable that contains all original cab datasets as a list of data frames
profiles_list = []

for file_name in select_files:
    file_path = os.path.join(source_files_path, file_name)
    df = pd.read_csv(file_path, sep=" ", header=None, names=["Latitude", "Longitude", "Occupied", "Timestamp"])
    df["FileName"] = file_name[:-4]
    df = df.drop(columns="Occupied")
    profiles_list.append(df)

# %%
## Load synthetic cabspotting sets from pickle

# Files path
files_path = Path("Repository/LDTP_Trace/notebooks-ldptrace/output/cabspotting-single/pickles")
source_files_path =  os.path.join(src_path, files_path)

all_files = os.listdir(source_files_path)

pickle_files = [file for file in all_files if file.endswith('.pkl')]

# Global variable that contains all synthetic cab datasets as a list of data frames
synthetic_profiles = []

for file_name in pickle_files:
    with open(f"{source_files_path}/{file_name}", 'rb') as f:
        trajectories = pickle.load(f)

    data_points = []

    # By default, synthetic trajectories contain multiple sub trajectories with one or multiple data points. To allow processing in HMC, this dimensionality is removed.
    # All subtrajectories are split and merged into single data points, conserving the original order.
    for trajectory in trajectories:
        for coord_pair in trajectory:
            longitude, latitude = coord_pair
            data_points.append([latitude, longitude])
            
    df = pd.DataFrame(data_points, columns=["Latitude", "Longitude"])
    df["FileName"] = file_name[:-4]
    synthetic_profiles.append(df)

# %%
def monitor_memory(stop_event):

    global current_memory_usage
    global memory_highest_value
    global memory_monitor_output
    
    while not stop_event.is_set():
        mem = psutil.virtual_memory()
        current_memory_usage = mem.percent

        if mem.percent > memory_highest_value:
            memory_highest_value = mem.percent

        if memory_monitor_output:
            print(f"Current memory usage: {mem.percent}, highest memory usage: {memory_highest_value}")
            
        time.sleep(1)

# %%
def split_single_dataframe(selected_profile):

    """
    (DEPRECATED) Splits a single trajectory (data set) in sub trajectories, depending on the value in "Occupied". A sub trajectory beigns and ends when the value of "Occupied" changes
    """
    
    # Find start of trajectory
    start_traj = selected_profile['Occupied'].diff() == 1

    # Find end of trajcetory
    end_traj = selected_profile['Occupied'].diff() == -1

    # Create new trajectory
    selected_profile['Trajectory_ID'] = (start_traj.cumsum() + end_traj.cumsum()).fillna(0).astype(int)

    # Group data frame by trajectory id
    grouped = selected_profile.groupby('Trajectory_ID')

    # Save trajectories in dictionary
    trajectories_list = [group.copy() for _, group in grouped]

    return trajectories_list

# %%
def split_data_frame_list_by_date(profiles_list):

    """
    Splits a single data set into two (one as a baseline data set, the other one as a comparee data set) - Based upon date (Timestamp)
    """

    first_80_percent = []
    last_20_percent = []

    # 29.05.2008 -> 50/50 Split     06.04.2008 -> 80/20 Split
    time_limit_str = "29.05.2008 23:59"
    datetime_limit = datetime.strptime(time_limit_str,'%d.%m.%Y %H:%M')


    for df in profiles_list:
        df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
        df = df.sort_values('Timestamp')

        split_index = df[df['Timestamp'] > datetime_limit].first_valid_index()

        if split_index is not None:
            first_80_df = df.loc[:split_index - 1]
            first_80_df = first_80_df.loc[::5]
            last_20_df = df.loc[split_index:]
            last_20_df = last_20_df.loc[::5]
        else:
            first_80_df = df
            last_20_df = pd.DataFrame()

        first_80_percent.append(first_80_df)
        last_20_percent.append(last_20_df)

    return first_80_percent, last_20_percent

# %%
def split_data_frame_list_top_30(profiles_list):

    """
    Splits a single data set in half - Based upon the 30 most active days (days with most data points) for each individual profile
    """

    first_part = []
    last_part = []

    for df in profiles_list:

        df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
        df['Date'] = df['Timestamp'].dt.date
        
        date_grouped = df.groupby('Date').size().reset_index(name='counts')
        
        top_30_days = date_grouped.nlargest(30, 'counts')['Date']
        
        first_half_df = pd.DataFrame()
        last_half_df = pd.DataFrame()
        
        for day in top_30_days:
            day_entries = df[df['Date'] == day]
            day_entries = day_entries.sort_values('Timestamp')
            mid_point = len(day_entries) // 2
            
            first_half = day_entries.iloc[:mid_point]
            last_half = day_entries.iloc[mid_point:]
            
            first_half_df = pd.concat([first_half_df, pd.DataFrame(first_half)], ignore_index=True)
            last_half_df = pd.concat([last_half_df, pd.DataFrame(last_half)], ignore_index=True)
        
        first_part.append(first_half_df)
        last_part.append(last_half_df)

    return first_part, last_part

# %%
def split_data_frame_list_randomly(profiles_list, seed = 123):

    """
    Splits each DataFrame in a list of DataFrames into two halves with random lengths
    """
    np.random.seed(seed)

    first_part = []
    last_part = []

    for df in profiles_list:
        if len(df) > 1:
            split_index = np.random.randint(1, len(df))
            first_part_df = df.iloc[:split_index]
            last_part_df = df.iloc[split_index:]
        else:
            first_part_df = df
            last_part_df = pd.DataFrame()

        first_part.append(first_part_df)
        last_part.append(last_part_df)

    return first_part, last_part

# %%
def split_data_frame_list_by_half(profiles_list):

    """
    Splits each DataFrame in a list of DataFrames into two halves
    """

    first_50_percent = []
    last_50_percent = []

    for df in profiles_list:
        if len(df) > 1:
            split_index = len(df) // 2
            first_part_df = df.iloc[:split_index]
            last_part_df = df.iloc[split_index:]
        else:
            first_part_df = df
            last_part_df = pd.DataFrame()

        first_50_percent.append(first_part_df)
        last_50_percent.append(last_part_df)

    return first_50_percent, last_50_percent

# %%
def split_data_frame_list_by_cluster(profiles_list):

    first_half_list = []
    last_half_list = []

    for profile in profiles_list:
        if len(profile) > 1:  # Check if the DataFrame contains at least two data points
            # Calculate the number of clusters, limited to a minimum of 3 and a maximum of 5
            num_clusters = max(3, min(5, len(profile) // 2))
            # Perform K-Means clustering to identify clusters of geographic regions
            kmeans = KMeans(n_clusters=num_clusters, random_state=42)
            profile['Cluster'] = kmeans.fit_predict(profile[['Latitude', 'Longitude']])

            # Randomly split each cluster into two parts
            cluster_data_frames = []
            for cluster in range(num_clusters):
                cluster_data = profile[profile['Cluster'] == cluster]
                split_point = len(cluster_data) // 2
                shuffled_indices = np.random.permutation(cluster_data.index)
                first_part = cluster_data.loc[shuffled_indices[:split_point]]
                second_part = cluster_data.loc[shuffled_indices[split_point:]]
                cluster_data_frames.append((first_part, second_part))

            # Combine the parts of all clusters
            first_parts = pd.concat([df[0] for df in cluster_data_frames], ignore_index=True)
            last_parts = pd.concat([df[1] for df in cluster_data_frames], ignore_index=True)

            # Store the parts in the lists
            first_half_list.append(first_parts[['Longitude', 'Latitude', 'FileName']])
            last_half_list.append(last_parts[['Longitude', 'Latitude', 'FileName']])
        else:
            # If there are fewer than two data points, add the entire DataFrame to both lists
            first_half_list.append(profile[['Longitude', 'Latitude', 'FileName']])
            last_half_list.append(profile[['Longitude', 'Latitude', 'FileName']])

    return first_half_list, last_half_list

# %%
def calculate_map_bins(long_upper = lon_max, long_lower = lon_min, lat_upper = lat_max, lat_lower = lat_min, num_lon_bins = num_lon_bins, num_lat_bins = num_lat_bins):
    """
    Calculates the map bins of the grid, based upon the specified values for latitude, longitude and the amount of grid cells.
    
    Args:
    - long_upper: Upper limit of the longitude.
    - long_lower: Lower limit of the longitude.
    - lat_upper: Upper limit of the latitude.
    - lat_lower: Lower limit of the latitude.
    - num_lon_bins: Number of longitude bins.
    - num_lat_bins: Number of latitude bins.
    
    Returns:
    - bin_rows: DataFrame containing the calculated bins with their limits.
    """
    
    long_total = long_upper - long_lower
    lat_total = lat_upper - lat_lower

    long_bin_size = long_total / num_lon_bins
    lat_bin_size = lat_total / num_lat_bins

    bin_rows = pd.DataFrame({
        "Index": range(num_lat_bins * num_lon_bins)
    })

    bin_rows['Longitude Lower Limit'] = long_lower + (bin_rows['Index'] % num_lon_bins) * long_bin_size
    bin_rows['Longitude Upper Limit'] = bin_rows['Longitude Lower Limit'] + long_bin_size
    bin_rows['Latitude Upper Limit'] = lat_upper - (bin_rows['Index'] // num_lon_bins) * lat_bin_size
    bin_rows['Latitude Lower Limit'] = bin_rows['Latitude Upper Limit'] - lat_bin_size

    return bin_rows

map_bins = calculate_map_bins()

# %%
def calculate_distance_between_points(array_a, array_b, distance_type="hausdorff", seed=0):
    if distance_type == "topsoe":
        return calculate_topsoe_divergence(array_a, array_b)
    elif distance_type == "hausdorff":
        return calculate_hausdorff_distance(array_a, array_b, seed)
    else:
        raise Exception("Missing selection of distance calculation algorithm!")

# %%
def calculate_topsoe_divergence(P_ij, Q_ij):
    return np.sum(P_ij * np.log(2 * P_ij / (P_ij + Q_ij))) + np.sum(Q_ij * np.log(2 * Q_ij / (P_ij + Q_ij)))

# %%
def calculate_hausdorff_distance(array_a, array_b, seed):
    return scipy.spatial.distance.directed_hausdorff(array_a, array_b, seed)[0]

# %%
def create_heatmap(df, lon_bins = num_lon_bins, lat_bins = num_lat_bins, density = True):
    """
    Create a heat map based on the given DataFrame. By default returns a probability density heat map.
    
    Args:
    - df: DataFrame containing 'Latitude' and 'Longitude' columns.
    - lon_min: Minimum longitude for the bins.
    - lon_max: Maximum longitude for the bins.
    - lat_min: Minimum latitude for the bins.
    - lat_max: Maximum latitude for the bins.
    - num_lon_bins: Number of longitude bins.
    - num_lat_bins: Number of latitude bins.
    - density: If True, normalize the heat map to represent probability density.
    
    Returns:
    - hist: 2D histogram representing the heat map.
    """
    
    lat = df["Latitude"].values
    lon = df["Longitude"].values

    # Create grid from longitude / latitude data points
    lon_bins = np.linspace(lon_min, lon_max, num_lon_bins)
    lat_bins = np.linspace(lat_min, lat_max, num_lat_bins)

    # Create 2D histogram
    hist, _, _ = np.histogram2d(lon, lat, bins=[lon_bins, lat_bins], density=density)
    
    # Replace zero values with a small number to avoid issues with log calculations
    hist[hist == 0] = 1e-10
    
    return hist

# %%
def show_heat_map(heat_map, title = ""):

    """
    Displays given heat map in the console
    """

    plt.imshow(heat_map.T, origin='lower', extent=[lon_min, lon_max, lat_min, lat_max], aspect='auto', cmap='magma')

    plt.colorbar()
    plt.title(title)
    
    plt.show()

# %%
def visited_bins(profile, map_bins = map_bins):
    """
    Calculates the visited bins (grid cells) of a given DataFrame
    
    Args:
    - profile: DataFrame containing longitude and latitude columns.
    - map_bins: DataFrame containing the bin definitions with columns:
        ['Longitude Lower Limit', 'Longitude Upper Limit', 
         'Latitude Lower Limit', 'Latitude Upper Limit', 'Index']
         
    Returns:
    - sorted_bins: Array of unique visited bin indices, sorted.
    """
    
    # Initialize an empty list to store the indices of visited bins
    visited_bins = []

    # Iterate through each bin definition in map_bins
    for _, bin_row in map_bins.iterrows():
        # Find all profile entries that fall within the current bin
        in_bin = profile[
            (profile["Longitude"] >= bin_row["Longitude Lower Limit"]) &
            (profile["Longitude"] < bin_row["Longitude Upper Limit"]) &
            (profile["Latitude"] >= bin_row["Latitude Lower Limit"]) &
            (profile["Latitude"] < bin_row["Latitude Upper Limit"])
        ]
        if not in_bin.empty:
            visited_bins.append(bin_row["Index"])

    # Get unique and sorted bin indices
    unique_bins = np.unique(visited_bins)
    sorted_bins = np.sort(unique_bins)
    
    return sorted_bins

# %%
def remove_profiles_out_of_bounds_coordinates(profiles_list, lon_max = lon_max, lon_min = lon_min, lat_max = lat_max, lat_min = lat_min):
    """
    Removes coordinate points that are outliers and outside the specified part of the map 
    (outside min/max latitude/longitude range) to prevent out of bound errors.
    
    Args:
    - profiles_list: List of DataFrames containing profiles with 'Longitude' and 'Latitude' columns.
    - lon_max: Maximum allowed longitude.
    - lon_min: Minimum allowed longitude.
    - lat_max: Maximum allowed latitude.
    - lat_min: Minimum allowed latitude.
    
    Returns:
    - cleaned_profiles_list: List of DataFrames with out of bounds coordinates removed.
    """
    
    cleaned_profiles_list = []
    
    for df in profiles_list:
        cleaned_df = df[
            (df["Longitude"] <= lon_max) &
            (df["Longitude"] >= lon_min) &
            (df["Latitude"] <= lat_max) &
            (df["Latitude"] >= lat_min)
        ]
        cleaned_profiles_list.append(cleaned_df.reset_index(drop=True))
    
    return cleaned_profiles_list

# %%
def area_coverage_precision(visited_bins_h, visited_bins_candidate):
    """
    Formula to calculate utility (area coverage). See paper for reference.
    """
    if len(visited_bins_candidate) == 0:
        return 0
    return len(set(visited_bins_h).intersection(visited_bins_candidate)) / len(visited_bins_candidate)

# %%
def area_coverage_recall(visited_bins_h, visited_bins_candidate):
    """
    Formula to calculate utility (area coverage). See paper for reference.
    """
    if len(visited_bins_h) == 0:
        return 0
    return len(set(visited_bins_h).intersection(visited_bins_candidate)) / len(visited_bins_h)

# %%
def calculate_area_coverage(visited_bins_h, visited_bins_candidate):
    """
    Calculate utility (area coverage) between two heat maps. See paper for reference.
    """
    precision = area_coverage_precision(visited_bins_h, visited_bins_candidate)
    recall = area_coverage_recall(visited_bins_h, visited_bins_candidate)
    return (2 * precision * recall) / (precision + recall) if (precision + recall) != 0 else 0

# %%
def update_alteration_counter(counter, h, h_dash, u, v, reset):

    """
    During heat map alteration process, reset counter if topsoe divergence between H & V gets smaller (faster) compared to topsoe divergence between H & F. There exists
    a specified diff_previous value to prevent extremly long loops with barely any improvements
    """
    
    if reset:
        counter = 0 
    else:
        counter += 1 
    return counter

# %%
def get_profile_u(heat_map_h, precomputed_profiles):

    """
    Selects profile u, the profile with the highest similarity (lowest topsoe divergence)
    """

    smallest_value = np.inf
    selected_candidate_id = None

    # Determine profile u, profile with the smallest topsoe divergence to the profile that shall be obfuscated, that is not the profile to obfuscate itself
    for profile_candidate_id, data_candidate in precomputed_profiles.items():

        topsoe_distance = calculate_distance_between_points(heat_map_h, data_candidate.heat_map)
        
        if topsoe_distance < smallest_value and topsoe_distance >= 0:
            smallest_value = topsoe_distance
            selected_candidate_id = profile_candidate_id
    
    return precomputed_profiles[selected_candidate_id]

# %%
def get_profile_v(profile_h, precomputed_profiles):
    """
    Select profile v, the profile with the highest area coverage (utility) with profile h (profile to obfuscate).

    Args:
    - profile_h: The profile to be obfuscated.
    - precomputed_profiles: A dictionary containing precomputed profiles.

    Returns:
    - The profile with the highest area coverage with profile_h.
    """
    biggest_value = 0
    selected_candidate_id = None
    profile_h_visited_bins = profile_h.visited_bins

    # Remove profile_h from precomputed_profiles
    precomputed_profiles_sans_h = {k: v for k, v in precomputed_profiles.items() if k != profile_h.profile_data.iloc[0][identifier_column]}

    # Determine profile v, profile with the best utility (highest area coverage)
    for profile_candidate_id, data_candidate in precomputed_profiles_sans_h.items():
        if len(data_candidate.visited_bins) != 0:
            f_score = calculate_area_coverage(profile_h_visited_bins, data_candidate.visited_bins)
        else:
            print(f"0 Bins found for profile {profile_candidate_id}?!")
            continue

        if f_score > biggest_value:
            biggest_value = f_score
            selected_candidate_id = profile_candidate_id
    
    return precomputed_profiles[selected_candidate_id]

# %%
def heat_map_alteration(profile_h, obfuscation_factor, all_precomputed_profiles, max_count_iterations):
    """
    Modify a heat map based on given datasets and obfuscation parameters.

    Args:
    - profile_h: The target profile to be obfuscated.
    - obfuscation_factor: The factor determining the extent of obfuscation.
    - all_precomputed_profiles: A dictionary containing precomputed profiles.
    - max_count_iterations: The maximum number of iterations allowed for alteration.

    Returns:
    - Modified heat map of profile_h.
    - Counter for the number of iterations performed.
    """
    gc.collect()

    try:
        func_timer = timer()
        print(f"Starting {inspect.currentframe().f_code.co_name} at: {datetime.now()}")

        # Get the number of data points in profile_h
        amount_data_points_H = len(profile_h.profile_data)
        # Get the identifier column from profile_h
        profile_h_id = profile_h.profile_data.iloc[0][identifier_column]
        # Get the heat map of profile_h
        heat_map_h = profile_h.heat_map

        counter_while = 0
        
        # Get profile_u based on heat_map_h
        timer_u = timer()
        profile_u = get_profile_u(heat_map_h, all_precomputed_profiles)
        
        profile_u_id = profile_u.profile_data.iloc[0][identifier_column]

        # If h and u belong to a different owner, no need to obfuscation
        if profile_u_id != profile_h_id:
            print(f"Profile U: {profile_u_id} Profile H: {profile_h_id} belong to a different owner. No need for obfuscation. Returning H.")
            return heat_map_h, counter_while

        # Filter out profile_u from all_precomputed_profiles
        filtered_precomputed_profiles = {profile_id: data for profile_id, data in all_precomputed_profiles.items() if profile_id != profile_u_id}

        # Get profile_u again after filtering
        profile_u = get_profile_u(heat_map_h, filtered_precomputed_profiles)

        profile_u_id = profile_u.profile_data.iloc[0][identifier_column]

        # Further filter to ensure profile_u is not used for profile_v selection
        filtered_precomputed_profiles_for_v = {profile_id: data for profile_id, data in filtered_precomputed_profiles.items() if profile_id != profile_u_id}

        # Get profile_v based on profile_h_visited_bins
        profile_v = get_profile_v(profile_h, filtered_precomputed_profiles_for_v)
        
        profile_v_id = profile_v.profile_data.iloc[0][identifier_column]

        counter_obfuscation = 0

        # Get heat maps of profile_u and profile_v
        heat_map_u = filtered_precomputed_profiles[profile_u_id].heat_map
        heat_map_v = all_precomputed_profiles[profile_v_id].heat_map

        # Debug output to ensure U and V are different
        #print(f"Profile H ID: {profile_h_id},Profile U ID: {profile_u_id}, Profile V ID: {profile_v_id}")
        #print(f"Topsoe Divergence U-V: {calculate_distance_between_points(heat_map_u, heat_map_v)}")

        if profile_u_id == profile_v_id:
            raise ValueError("Profile U and Profile V should not be the same")

        heat_map_h_dash = heat_map_h
        diff_previous = 0

        while (calculate_distance_between_points(heat_map_h_dash, heat_map_v) > calculate_distance_between_points(heat_map_h_dash, heat_map_u) 
                and counter_obfuscation <= max_count_iterations and counter_while < 150000): # Hard cap for iterations to avoid out of memory scenarios
            
            #mem = psutil.virtual_memory() 
            #if mem.percent > memory_threshold:
            #    print("Memory usage too high. Cancelling Heat Map Alteration and returning Heat Map V as a substitute.")
            #    return heat_map_v, counter_while

            # Calculate matrices for obfuscation
            matrix_r = heat_map_h_dash * amount_data_points_H
            matrix_w = heat_map_h_dash * heat_map_v * (1 - heat_map_u)
            matrix_o = matrix_r + ((obfuscation_factor/np.sum(matrix_w)) *  matrix_w)
            matrix_h_dash = (1 / amount_data_points_H) * matrix_o

            topsoe_divergence_h_v = calculate_distance_between_points(heat_map_h_dash, heat_map_v)
            topsoe_divergence_h_u = calculate_distance_between_points(heat_map_h_dash, heat_map_u)

            counter_while += 1

            if (topsoe_divergence_h_v - topsoe_divergence_h_u) < diff_previous:
                counter_obfuscation = update_alteration_counter(counter_obfuscation, heat_map_h_dash, matrix_h_dash, heat_map_u, heat_map_v, True)
                heat_map_h_dash = matrix_h_dash
                diff_previous = topsoe_divergence_h_v - topsoe_divergence_h_u
                continue

            counter_obfuscation = update_alteration_counter(counter_obfuscation, heat_map_h_dash, matrix_h_dash, heat_map_u, heat_map_v, False)
            heat_map_h_dash = matrix_h_dash
            diff_previous = topsoe_divergence_h_v - topsoe_divergence_h_u

        print(f"Iteration {counter_while} finished. Topsoe Divergence H V = {calculate_distance_between_points(heat_map_h_dash, heat_map_v)} Topsoe Divergence H U = {calculate_distance_between_points(heat_map_h_dash, heat_map_u)}")
        print(f"{inspect.currentframe().f_code.co_name} execution finished after {timer() - func_timer} seconds")

        if counter_obfuscation >= max_count_iterations:
            print(f"No solution found within {counter_while} iterations. Returning heat map V as a substitute.")
            return heat_map_v, counter_while

        return heat_map_h_dash, counter_while

    finally:
        # Cleanup code to free resources
        gc.collect()
        #print(f"Resources have been cleaned up after {inspect.currentframe().f_code.co_name}")

# %%
def modify_number_of_records(mobility_trace, amount_target_datapoints):
    P = mobility_trace.copy()
    P['Timestamp'] = pd.to_datetime(P['Timestamp'], format='%d.%m.%Y %H:%M', errors='coerce')
    P_dash = pd.DataFrame(columns=P.columns)

    while len(P_dash) < amount_target_datapoints:
        P_dash = pd.concat([P_dash, P.iloc[[0]]], ignore_index=True)

        for i in range(1, len(P)):
            p_mid = pd.DataFrame(index=[0], columns=P.columns)
            p_mid["Longitude"] = (P["Longitude"].iloc[i - 1] + P["Longitude"].iloc[i]) / 2
            p_mid["Latitude"] = (P["Latitude"].iloc[i - 1] + P["Latitude"].iloc[i]) / 2
            
            timestamp_difference = (P["Timestamp"].iloc[i] - P["Timestamp"].iloc[i - 1]) / 2
            p_mid["Timestamp"] = P["Timestamp"].iloc[i - 1] + timestamp_difference

            P_dash = pd.concat([P_dash, p_mid], ignore_index=True)
            P_dash = pd.concat([P_dash, P.iloc[[i]]], ignore_index=True)
            #print("Added entry at index", i)

        P = P_dash.copy()

    print(P.head(100))
    P["FileName"] = P["FileName"][0]
    #print(P)
    print(f"Original Length: {len(mobility_trace)} New Length: {len(P)}")
    #random_selection = random.choices(P, weights = None, cum_weights = None, k = amount_target_datapoints)
    #print(random_selection)
    return P

# %%
### Scenario 1: Execute AP-Attack on the HMC obfuscated data sets  

"""
Select which data set shall be used
# !! Important: The synthetic_profiles by default DO NOT have a Timestamp component, which means that splits BY DATE are NOT possible !!
"""

# Allowed keywords "SYNTHETIC" or "NORMAL"
scenarios = ["SYNTHETIC", "NORMAL"]
# Allowed keywords "HALF" or "RANDOM" or "CLUSTER"
split_algorithm = ["RANDOM"]

# Seeds generated with https://www.random.org/ True Random Number Generator, Params Min: 1, Max: 10000
random_seeds = [8046]#, 8251, 8166, 435, 7782, 9807, 3582, 21, 5446, 781]



def process_data(split_algorithm, scenarios, seed):
    try:
        for algorithm in split_algorithm:
            for scenario in scenarios:
                dataset_type = scenario

                # Select data set
                if dataset_type == "SYNTHETIC":
                    profiles_list_cleansed = remove_profiles_out_of_bounds_coordinates(synthetic_profiles)
                    print("Synthetic data set selected")
                elif dataset_type == "NORMAL":
                    profiles_list_cleansed = remove_profiles_out_of_bounds_coordinates(profiles_list)
                    print("Normal data set selected")
                else:
                    print(f"No dataset {scenario} could be found!")
                    sys.exit()

                # Select split function
                if algorithm == "HALF":
                    first_50, last_50 = split_data_frame_list_by_half(profiles_list_cleansed)
                elif algorithm == "RANDOM":
                    first_50, last_50 = split_data_frame_list_randomly(profiles_list_cleansed, seed)
                elif algorithm == "CLUSTER":
                    first_50, last_50 = split_data_frame_list_by_cluster(profiles_list)
                else:
                    print(f"No Split Algorithm {algorithm} could be found!")
                    continue

                first_50 = list(filter(lambda df: not df.empty, first_50))
                last_50 = list(filter(lambda df: not df.empty, last_50))

                output_folder_path = Path('Daten/Ausgabe/AP Scenario HMC 50_50')
                output_folder = src_path / output_folder_path
                os.makedirs(output_folder, exist_ok=True)

                results = []

                save_interval = 5  # save every 5 results
                now = datetime.now()
                formatted_date = now.strftime("%Y%m%d_%H%M%S")
                output_path = os.path.join(output_folder, f"ap_output_HMC_{dataset_type}_{algorithm}_{formatted_date}_SEED{seed}.csv")

                # Precompute heatmaps and visited bins
                @dataclass
                class ProfileData:
                    profile_data: pd.DataFrame
                    visited_bins: any
                    heat_map: any

                func_timer = timer()  # Timer für die Precomputation starten
                print("Starting pre computation at: ", datetime.now())
                precomputed_profile_data_first = {
                    profile.iloc[0][identifier_column]: ProfileData(
                        profile_data=profile,
                        visited_bins=visited_bins(profile),
                        heat_map=create_heatmap(profile)
                    )
                    for profile in first_50
                }

                precomputed_profile_data_last = {
                    profile.iloc[0][identifier_column]: ProfileData(
                        profile_data=profile,
                        visited_bins=visited_bins(profile),
                        heat_map=create_heatmap(profile)
                    )
                    for profile in last_50
                }

                print("Pre computation took", timer() - func_timer, "seconds")

                # Iterate over all the baseline profiles (from first_50)
                j = 1
                for profile_id_baseline, data_baseline in precomputed_profile_data_first.items():
                    i = 1

                    smallest_distance = np.inf
                    smallest_distance_name = ""
                    obfuscation_factor = max(len(precomputed_profile_data_first[profile_id_baseline].profile_data) / 500, 50)
                    obfuscated_baseline, amount_iterations = heat_map_alteration(precomputed_profile_data_first[profile_id_baseline], obfuscation_factor, precomputed_profile_data_last, 1000)

                    for _, data_comparee in precomputed_profile_data_last.items():

                        topsoe_divergence = calculate_distance_between_points(obfuscated_baseline, data_comparee.heat_map)

                        if topsoe_divergence < smallest_distance and topsoe_divergence > 0:
                            smallest_distance = topsoe_divergence
                            smallest_distance_name = data_comparee.profile_data["FileName"].iloc[0]

                        if smallest_distance == 0:
                            raise ValueError("smallest_distance should never be = 0")

                        i += 1

                    results.append({
                        'Baseline': data_baseline.profile_data["FileName"].iloc[0],
                        'Comparee': smallest_distance_name,
                        'Distance': smallest_distance,
                        'Iterations': amount_iterations,
                        "Equal File Name": "Yes" if smallest_distance_name == data_baseline.profile_data["FileName"].iloc[0] else "No"
                    })

                    j += 1

                    if len(results) >= save_interval:
                        results_df = pd.DataFrame(results)
                        if os.path.exists(output_path):
                            results_df.to_csv(output_path, mode='a', header=False, index=False)
                        else:
                            results_df.to_csv(output_path, index=False)
                        results = []
                        gc.collect()

                # Save any remaining results
                if results:
                    results_df = pd.DataFrame(results)
                    if os.path.exists(output_path):
                        results_df.to_csv(output_path, mode='a', header=False, index=False)
                    else:
                        results_df.to_csv(output_path, index=False)
                    results = []
                    gc.collect()

                # Calculate additional metrics
                final_results_df = pd.read_csv(output_path)
                final_results_df['Row_Count'] = len(final_results_df)
                yes_count = final_results_df['Equal File Name'].value_counts().get('Yes', 0)
                no_count = final_results_df['Equal File Name'].value_counts().get('No', 0)
                total_count = yes_count + no_count
                final_results_df['Total_Yes'] = yes_count
                final_results_df['Total_No'] = no_count
                final_results_df['Percentage_Yes'] = (yes_count / total_count) * 100 if total_count > 0 else 0
                final_results_df['Percentage_No'] = (no_count / total_count) * 100 if total_count > 0 else 0

                final_results_df.to_csv(output_path, index=False)

    finally:
        stop_event.set()  # Set the event to stop the monitor thread

for seed in random_seeds:
    process_data(split_algorithm, scenarios, seed)

    
## Start the memory monitoring in a separate thread
#monitor_thread = threading.Thread(target=monitor_memory, args=(stop_event,))
#monitor_thread.daemon = True
#monitor_thread.start()

# Start the data processing in a separate thread
#processing_thread = threading.Thread(target=process_data, args=(split_algorithm, scenarios, stop_event))
#processing_thread.start()

# Wait for the processing to finish
#processing_thread.join()

# Ensure the monitor thread is stopped
#monitor_thread.join()
# Out:
# Synthetic data set selected
# Starting pre computation at:  2024-07-20 12:31:25.001958
# Pre computation took 31.768548699999883 seconds
# Starting heat_map_alteration at: 2024-07-20 12:31:56.943162
# Iteration 25418 finished. Topsoe Divergence H V = 434.82405926064627 Topsoe Divergence H U = 434.825021162104
# heat_map_alteration execution finished after 19.902221799999097 seconds
# Starting heat_map_alteration at: 2024-07-20 12:32:17.215544
# Profile U: new_ifanfadd Profile H: new_abcoij belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:32:17.682697
# Profile U: new_ocshitcl Profile H: new_abdremlu belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:32:18.153851
# Iteration 1001 finished. Topsoe Divergence H V = 194.26148843877937 Topsoe Divergence H U = 42.121961100067566
# heat_map_alteration execution finished after 1.0449277999996411 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:32:19.566422
# Profile U: new_inlica Profile H: new_abjoolaw belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:32:20.185883
# Iteration 1001 finished. Topsoe Divergence H V = 133.55919907665182 Topsoe Divergence H U = 40.10815496315783
# heat_map_alteration execution finished after 0.9790173000001232 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:32:21.543609
# Iteration 1001 finished. Topsoe Divergence H V = 103.4812224895026 Topsoe Divergence H U = 41.33054480364416
# heat_map_alteration execution finished after 0.9754768000002514 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:32:22.886108
# Iteration 1001 finished. Topsoe Divergence H V = 194.75538903465576 Topsoe Divergence H U = 98.16639764977599
# heat_map_alteration execution finished after 0.9706717000008211 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:32:24.242951
# Iteration 45395 finished. Topsoe Divergence H V = 582.5034948652749 Topsoe Divergence H U = 582.504071400454
# heat_map_alteration execution finished after 35.65232649999962 seconds
# Starting heat_map_alteration at: 2024-07-20 12:33:00.271927
# Profile U: new_irjfen Profile H: new_abwecnij belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:33:00.877219
# Iteration 1001 finished. Topsoe Divergence H V = 184.1429020648177 Topsoe Divergence H U = 74.69596903342219
# heat_map_alteration execution finished after 0.9802195000011125 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:33:02.229533
# Profile U: new_avpavi Profile H: new_acdiyito belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:33:02.715645
# Iteration 4581 finished. Topsoe Divergence H V = 97.805606391596 Topsoe Divergence H U = 48.00672914316294
# heat_map_alteration execution finished after 3.704585600000428 seconds
# No solution found within 4581 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:33:06.804908
# Iteration 1001 finished. Topsoe Divergence H V = 326.4764685377161 Topsoe Divergence H U = 85.52764384759139
# heat_map_alteration execution finished after 0.9817865999993955 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:33:08.214839
# Profile U: new_enyenewl Profile H: new_acitva belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:33:08.889028
# Iteration 2597 finished. Topsoe Divergence H V = 140.1801647785723 Topsoe Divergence H U = 140.18839964175913
# heat_map_alteration execution finished after 2.1595849999994243 seconds
# Starting heat_map_alteration at: 2024-07-20 12:33:11.428933
# Iteration 12830 finished. Topsoe Divergence H V = 138.89146166956118 Topsoe Divergence H U = 138.89365690313738
# heat_map_alteration execution finished after 10.018415200000163 seconds
# Starting heat_map_alteration at: 2024-07-20 12:33:21.809182
# Iteration 150000 finished. Topsoe Divergence H V = 239.99099633494257 Topsoe Divergence H U = 197.90000284963048
# heat_map_alteration execution finished after 112.51438049999888 seconds
# Starting heat_map_alteration at: 2024-07-20 12:35:14.689864
# Profile U: new_insodfl Profile H: new_adkavy belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:35:15.149396
# Iteration 1734 finished. Topsoe Divergence H V = 113.9549172738971 Topsoe Divergence H U = 113.9681216316067
# heat_map_alteration execution finished after 1.4970248999998148 seconds
# Starting heat_map_alteration at: 2024-07-20 12:35:17.149656
# Iteration 1001 finished. Topsoe Divergence H V = 371.711715687522 Topsoe Divergence H U = 76.66547596560207
# heat_map_alteration execution finished after 0.9554895000001125 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:35:18.481357
# Iteration 150000 finished. Topsoe Divergence H V = 920.3534219087953 Topsoe Divergence H U = 917.9516722383466
# heat_map_alteration execution finished after 112.75505619999967 seconds
# Starting heat_map_alteration at: 2024-07-20 12:37:11.607888
# Profile U: new_okvats Profile H: new_afmorc belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:12.074926
# Iteration 1001 finished. Topsoe Divergence H V = 161.59911711929772 Topsoe Divergence H U = 58.530539998841036
# heat_map_alteration execution finished after 0.9529755999992631 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:37:13.405373
# Profile U: new_imwyojy Profile H: new_afsfat belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:14.001283
# Iteration 1001 finished. Topsoe Divergence H V = 171.5282394707895 Topsoe Divergence H U = 55.86097624770282
# heat_map_alteration execution finished after 0.9545582999999169 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:37:15.333544
# Profile U: new_ektamy Profile H: new_agcowktu belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:15.808592
# Profile U: new_ecfesy Profile H: new_agdrea belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:16.289671
# Profile U: new_itcemra Profile H: new_aggjuo belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:16.770671
# Profile U: new_eckecky Profile H: new_agivle belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:17.364609
# Iteration 29810 finished. Topsoe Divergence H V = 1362.9062455643718 Topsoe Divergence H U = 1179.3840866002347
# heat_map_alteration execution finished after 22.54395189999923 seconds
# No solution found within 29810 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:37:40.269793
# Profile U: new_igglitby Profile H: new_agsuec belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:40.733806
# Profile U: new_epabcadu Profile H: new_agvexpia belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:41.186838
# Profile U: new_ockihoba Profile H: new_agyamker belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:41.642838
# Profile U: new_iacbyb Profile H: new_aichash belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:37:42.233811
# Iteration 47601 finished. Topsoe Divergence H V = 782.2441801029424 Topsoe Divergence H U = 782.2447335898172
# heat_map_alteration execution finished after 35.93708509999851 seconds
# Starting heat_map_alteration at: 2024-07-20 12:38:18.569075
# Iteration 1001 finished. Topsoe Divergence H V = 102.73247056418573 Topsoe Divergence H U = 45.82253476066943
# heat_map_alteration execution finished after 0.9945575999990979 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:38:19.943179
# Iteration 147091 finished. Topsoe Divergence H V = 794.4669028494801 Topsoe Divergence H U = 649.1459767019812
# heat_map_alteration execution finished after 111.53464039999926 seconds
# No solution found within 147091 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:40:11.854371
# Iteration 1657 finished. Topsoe Divergence H V = 160.86214673614992 Topsoe Divergence H U = 69.59141721852932
# heat_map_alteration execution finished after 1.4622044999996433 seconds
# No solution found within 1657 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:40:13.668783
# Profile U: new_idjokva Profile H: new_aivtytan belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:40:14.249780
# Iteration 3050 finished. Topsoe Divergence H V = 93.26322797299605 Topsoe Divergence H U = 93.28513855144674
# heat_map_alteration execution finished after 2.49455560000024 seconds
# Starting heat_map_alteration at: 2024-07-20 12:40:17.106809
# Profile U: new_ibflsruc Profile H: new_ajixdo belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:40:17.549778
# Iteration 1001 finished. Topsoe Divergence H V = 166.94741707884222 Topsoe Divergence H U = 43.0717282989601
# heat_map_alteration execution finished after 0.9381208999984665 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:40:18.858375
# Iteration 1001 finished. Topsoe Divergence H V = 160.61757205053564 Topsoe Divergence H U = 54.92073726092063
# heat_map_alteration execution finished after 0.9439301999991585 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:40:20.153960
# Profile U: new_inquay Profile H: new_ajthof belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:40:20.723985
# Iteration 61609 finished. Topsoe Divergence H V = 228.75029841107852 Topsoe Divergence H U = 205.60349024210979
# heat_map_alteration execution finished after 46.32447189999948 seconds
# No solution found within 61609 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:41:07.427562
# Iteration 3579 finished. Topsoe Divergence H V = 105.23219722716604 Topsoe Divergence H U = 105.23516137560526
# heat_map_alteration execution finished after 2.8718660000013188 seconds
# Starting heat_map_alteration at: 2024-07-20 12:41:10.661024
# Iteration 1001 finished. Topsoe Divergence H V = 183.28879666922927 Topsoe Divergence H U = 58.074071290917125
# heat_map_alteration execution finished after 0.9517214999996213 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:41:12.014755
# Iteration 3933 finished. Topsoe Divergence H V = 150.1196847628483 Topsoe Divergence H U = 89.92061391737828
# heat_map_alteration execution finished after 3.19314999999915 seconds
# No solution found within 3933 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:41:15.589804
# Profile U: new_ifragcic Profile H: new_aldhidd belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:41:16.196514
# Profile U: new_edjiye Profile H: new_alnihi belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:41:16.664511
# Iteration 1001 finished. Topsoe Divergence H V = 160.29513464413543 Topsoe Divergence H U = 49.438583889339775
# heat_map_alteration execution finished after 1.0176967000006698 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:41:18.083634
# Iteration 1001 finished. Topsoe Divergence H V = 256.17469342732693 Topsoe Divergence H U = 74.49173900537157
# heat_map_alteration execution finished after 0.9950652999996237 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:41:19.431275
# Profile U: new_osacmu Profile H: new_amknywr belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:41:19.925274
# Profile U: new_effneomi Profile H: new_amnurgji belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:41:20.568277
# Profile U: new_oydtesa Profile H: new_amvefarl belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:41:21.051144
# Iteration 2689 finished. Topsoe Divergence H V = 86.5266408184213 Topsoe Divergence H U = 86.54794889462471
# heat_map_alteration execution finished after 2.2368135000015172 seconds
# Starting heat_map_alteration at: 2024-07-20 12:41:23.645088
# Profile U: new_ajixdo Profile H: new_ancedvab belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:41:24.124670
# Profile U: new_uklsdryo Profile H: new_ancorjo belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:41:24.616244
# Iteration 1001 finished. Topsoe Divergence H V = 158.83242410406464 Topsoe Divergence H U = 54.985447333006306
# heat_map_alteration execution finished after 0.9740059000014298 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:41:26.069329
# Iteration 58155 finished. Topsoe Divergence H V = 117.29572271054751 Topsoe Divergence H U = 117.29602374148463
# heat_map_alteration execution finished after 43.80436379999992 seconds
# Starting heat_map_alteration at: 2024-07-20 12:42:10.226571
# Profile U: new_imwyojy Profile H: new_aniajcr belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:42:10.702597
# Iteration 1001 finished. Topsoe Divergence H V = 84.31497387608928 Topsoe Divergence H U = 47.74481859064382
# heat_map_alteration execution finished after 0.9975920999986556 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:12.113421
# Iteration 1001 finished. Topsoe Divergence H V = 468.8796598931654 Topsoe Divergence H U = 78.48014534966164
# heat_map_alteration execution finished after 1.0033027999998012 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:13.493123
# Iteration 1001 finished. Topsoe Divergence H V = 250.9027152184575 Topsoe Divergence H U = 75.15471785091461
# heat_map_alteration execution finished after 0.9823290000003908 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:15.039197
# Iteration 621 finished. Topsoe Divergence H V = 59.958024856786295 Topsoe Divergence H U = 59.97185453762424
# heat_map_alteration execution finished after 0.6758654000004753 seconds
# Starting heat_map_alteration at: 2024-07-20 12:42:16.183384
# Iteration 1001 finished. Topsoe Divergence H V = 105.25081435345429 Topsoe Divergence H U = 62.66209920102679
# heat_map_alteration execution finished after 0.9863439000000653 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:17.546340
# Profile U: new_atzumbon Profile H: new_apigcyd belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:42:18.012315
# Iteration 37066 finished. Topsoe Divergence H V = 267.47279120956307 Topsoe Divergence H U = 147.25912796802857
# heat_map_alteration execution finished after 28.147227700001167 seconds
# No solution found within 37066 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:46.512577
# Iteration 1001 finished. Topsoe Divergence H V = 110.20782089993075 Topsoe Divergence H U = 43.13323609450495
# heat_map_alteration execution finished after 0.9528635999995458 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:47.960485
# Iteration 1001 finished. Topsoe Divergence H V = 128.47261318910876 Topsoe Divergence H U = 63.304262572179866
# heat_map_alteration execution finished after 0.9543063999990409 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:49.283863
# Iteration 1001 finished. Topsoe Divergence H V = 160.7929946775079 Topsoe Divergence H U = 41.10402580683489
# heat_map_alteration execution finished after 0.942930700000943 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:50.579744
# Profile U: new_aducrisi Profile H: new_arcuim belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:42:51.041744
# Profile U: new_ayquexar Profile H: new_arcurbig belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:42:51.510590
# Iteration 1001 finished. Topsoe Divergence H V = 169.0508307240694 Topsoe Divergence H U = 53.50973578615565
# heat_map_alteration execution finished after 0.9701732000012271 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:52.970654
# Profile U: new_oakpikoo Profile H: new_arlwras belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:42:53.415687
# Iteration 1001 finished. Topsoe Divergence H V = 88.0446054107195 Topsoe Divergence H U = 46.02007036815372
# heat_map_alteration execution finished after 0.9681149999996705 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:54.736388
# Profile U: new_ecjeody Profile H: new_artgagvu belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:42:55.189356
# Iteration 1001 finished. Topsoe Divergence H V = 313.22215596864163 Topsoe Divergence H U = 84.39103937434444
# heat_map_alteration execution finished after 0.9595212000003812 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:56.498801
# Iteration 1001 finished. Topsoe Divergence H V = 89.28069030890161 Topsoe Divergence H U = 39.086810637205204
# heat_map_alteration execution finished after 0.9432314000005135 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:42:57.915304
# Iteration 25847 finished. Topsoe Divergence H V = 1363.8104218868496 Topsoe Divergence H U = 1272.0051774737055
# heat_map_alteration execution finished after 19.04335759999958 seconds
# No solution found within 25847 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:43:17.309592
# Iteration 1001 finished. Topsoe Divergence H V = 76.02371699332903 Topsoe Divergence H U = 55.87981681552481
# heat_map_alteration execution finished after 0.9530020000001969 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:43:18.613005
# Iteration 1001 finished. Topsoe Divergence H V = 186.21290510838273 Topsoe Divergence H U = 54.99052054357236
# heat_map_alteration execution finished after 0.9399211999989348 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:43:19.904037
# Profile U: new_aivtytan Profile H: new_aswift belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:20.363974
# Profile U: new_omdrid Profile H: new_atcilav belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:20.934967
# Iteration 1001 finished. Topsoe Divergence H V = 192.14749269687013 Topsoe Divergence H U = 68.36519141351697
# heat_map_alteration execution finished after 0.9333160999995016 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:43:22.236937
# Profile U: new_aichash Profile H: new_atfrim belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:22.700271
# Profile U: new_uklsdryo Profile H: new_atidfi belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:23.146270
# Iteration 1001 finished. Topsoe Divergence H V = 133.99216278974055 Topsoe Divergence H U = 59.21725265677231
# heat_map_alteration execution finished after 0.9244765000003099 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:43:24.418239
# Profile U: new_evijcey Profile H: new_atsfiv belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:25.020753
# Iteration 9671 finished. Topsoe Divergence H V = 240.50218639196567 Topsoe Divergence H U = 240.50652905881384
# heat_map_alteration execution finished after 7.600243799999589 seconds
# Starting heat_map_alteration at: 2024-07-20 12:43:32.990318
# Iteration 5721 finished. Topsoe Divergence H V = 126.2170611525287 Topsoe Divergence H U = 59.49742228771705
# heat_map_alteration execution finished after 4.4369168000012 seconds
# No solution found within 5721 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:43:37.787355
# Profile U: new_ecjeody Profile H: new_auctjir belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:38.230287
# Profile U: new_ogofvoit Profile H: new_aupclik belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:38.678255
# Profile U: new_idjokva Profile H: new_aurjyen belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:39.272256
# Profile U: new_imwyojy Profile H: new_avdyab belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:39.733869
# Profile U: new_iotklojy Profile H: new_avglybic belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:43:40.214152
# Iteration 1001 finished. Topsoe Divergence H V = 133.90358885408 Topsoe Divergence H U = 45.14829553109109
# heat_map_alteration execution finished after 0.9430640999999014 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:43:41.522048
# Iteration 26518 finished. Topsoe Divergence H V = 333.7650009600948 Topsoe Divergence H U = 333.7682719365565
# heat_map_alteration execution finished after 19.848451400001068 seconds
# Starting heat_map_alteration at: 2024-07-20 12:44:01.734490
# Profile U: new_erjtail Profile H: new_awnbeb belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:44:02.366234
# Iteration 1001 finished. Topsoe Divergence H V = 211.53777289196327 Topsoe Divergence H U = 66.89816151937595
# heat_map_alteration execution finished after 1.0343005000013363 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:44:03.769474
# Profile U: new_eglohabs Profile H: new_awribig belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:44:04.299461
# Iteration 1001 finished. Topsoe Divergence H V = 222.10139885848048 Topsoe Divergence H U = 62.03594895136007
# heat_map_alteration execution finished after 0.970243699999628 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:44:05.625935
# Iteration 12217 finished. Topsoe Divergence H V = 163.51158171931962 Topsoe Divergence H U = 163.5131523508452
# heat_map_alteration execution finished after 9.534033500000078 seconds
# Starting heat_map_alteration at: 2024-07-20 12:44:15.522314
# Iteration 150000 finished. Topsoe Divergence H V = 9248.451438362414 Topsoe Divergence H U = 9161.128107012803
# heat_map_alteration execution finished after 112.98583259999941 seconds
# Starting heat_map_alteration at: 2024-07-20 12:46:08.998933
# Iteration 1790 finished. Topsoe Divergence H V = 118.23027802205344 Topsoe Divergence H U = 74.62788212337573
# heat_map_alteration execution finished after 1.5284563999994134 seconds
# No solution found within 1790 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:46:10.899196
# Profile U: new_ofjeequo Profile H: new_ayquasto belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:46:11.380226
# Profile U: new_oadwowd Profile H: new_ayquexar belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:46:11.846195
# Profile U: new_uljior Profile H: new_ayshekki belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:46:12.292195
# Profile U: new_icdaheos Profile H: new_ayshowg belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:46:12.905802
# Profile U: new_esudcejo Profile H: new_aysmsla belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:46:13.380340
# Iteration 1594 finished. Topsoe Divergence H V = 154.99797926240183 Topsoe Divergence H U = 155.04104453968876
# heat_map_alteration execution finished after 1.3988867999996728 seconds
# Starting heat_map_alteration at: 2024-07-20 12:46:15.165841
# Profile U: new_udwebir Profile H: new_eadectio belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:46:15.623843
# Profile U: new_elhuyoi Profile H: new_eagbaci belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:46:16.076844
# Iteration 1001 finished. Topsoe Divergence H V = 177.67460191287606 Topsoe Divergence H U = 66.34572052411029
# heat_map_alteration execution finished after 0.9675934000006237 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:46:17.612944
# Iteration 1001 finished. Topsoe Divergence H V = 118.4288316515069 Topsoe Divergence H U = 51.784085828214394
# heat_map_alteration execution finished after 0.9528007999997499 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:46:18.930966
# Iteration 1001 finished. Topsoe Divergence H V = 111.20739302943255 Topsoe Divergence H U = 47.87408113020171
# heat_map_alteration execution finished after 1.0225859999991371 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:46:20.360296
# Iteration 1001 finished. Topsoe Divergence H V = 232.6687505997816 Topsoe Divergence H U = 77.85673490511238
# heat_map_alteration execution finished after 1.0686533999996755 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:46:22.028966
# Profile U: new_udwadla Profile H: new_ebcicy belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:46:22.643889
# Iteration 150000 finished. Topsoe Divergence H V = 76677.029619713 Topsoe Divergence H U = 76576.37560723083
# heat_map_alteration execution finished after 115.1943984999998 seconds
# Starting heat_map_alteration at: 2024-07-20 12:48:18.327021
# Iteration 1001 finished. Topsoe Divergence H V = 103.09711609584471 Topsoe Divergence H U = 50.591722025189135
# heat_map_alteration execution finished after 0.9815748999990319 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:48:19.710444
# Profile U: new_anidgib Profile H: new_ebrulra belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:48:20.179377
# Iteration 8886 finished. Topsoe Divergence H V = 314.8744864409312 Topsoe Divergence H U = 292.66951855109744
# heat_map_alteration execution finished after 6.950994900000296 seconds
# No solution found within 8886 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:48:27.500149
# Iteration 1001 finished. Topsoe Divergence H V = 160.89648371427927 Topsoe Divergence H U = 57.12923714230733
# heat_map_alteration execution finished after 0.9525627999992139 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:48:28.822084
# Iteration 3355 finished. Topsoe Divergence H V = 85.71503748851362 Topsoe Divergence H U = 85.72175198867951
# heat_map_alteration execution finished after 2.7206675999987056 seconds
# Starting heat_map_alteration at: 2024-07-20 12:48:32.133424
# Iteration 69811 finished. Topsoe Divergence H V = 176.73743353645307 Topsoe Divergence H U = 176.73766983065713
# heat_map_alteration execution finished after 51.990322300000116 seconds
# Starting heat_map_alteration at: 2024-07-20 12:49:24.482683
# Iteration 3785 finished. Topsoe Divergence H V = 74.82427997024385 Topsoe Divergence H U = 50.098093219728675
# heat_map_alteration execution finished after 2.9826166999991983 seconds
# No solution found within 3785 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:49:27.837039
# Profile U: new_ootquoa Profile H: new_ecgojtyt belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:49:28.309414
# Profile U: new_ickguwa Profile H: new_ecjeody belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:49:28.762512
# Iteration 1001 finished. Topsoe Divergence H V = 238.60021483722858 Topsoe Divergence H U = 124.44208173521454
# heat_map_alteration execution finished after 0.9440548999991734 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:49:30.227878
# Profile U: new_ogjoch Profile H: new_ecnoplsi belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:49:30.690883
# Iteration 1001 finished. Topsoe Divergence H V = 169.77096076374977 Topsoe Divergence H U = 71.8489253617191
# heat_map_alteration execution finished after 0.9371637999993254 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:49:31.994367
# Iteration 1001 finished. Topsoe Divergence H V = 123.88986071547762 Topsoe Divergence H U = 33.27736768170181
# heat_map_alteration execution finished after 0.9851932999990822 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:49:33.354405
# Iteration 150000 finished. Topsoe Divergence H V = 7513.073226448912 Topsoe Divergence H U = 7506.578679635869
# heat_map_alteration execution finished after 110.34776480000073 seconds
# Starting heat_map_alteration at: 2024-07-20 12:51:24.067715
# Profile U: new_abwecnij Profile H: new_edgrat belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:51:24.659572
# Profile U: new_eghanwib Profile H: new_edjiye belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:51:25.128055
# Iteration 9419 finished. Topsoe Divergence H V = 91.33454858908244 Topsoe Divergence H U = 79.07196488951539
# heat_map_alteration execution finished after 7.113269899999068 seconds
# No solution found within 9419 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:51:32.616415
# Iteration 1001 finished. Topsoe Divergence H V = 107.5908480219756 Topsoe Divergence H U = 48.206937395725454
# heat_map_alteration execution finished after 0.9443226999992476 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:51:33.939159
# Profile U: new_ocjeng Profile H: new_ednillo belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:51:34.396851
# Profile U: new_eshria Profile H: new_edodblea belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:51:34.990890
# Profile U: new_oknscocy Profile H: new_edomboys belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:51:35.447900
# Iteration 1001 finished. Topsoe Divergence H V = 96.29365993128309 Topsoe Divergence H U = 60.97573831215722
# heat_map_alteration execution finished after 0.9521709000000556 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:51:36.765615
# Iteration 15306 finished. Topsoe Divergence H V = 98.014688024854 Topsoe Divergence H U = 59.65506808087434
# heat_map_alteration execution finished after 11.4435756999992 seconds
# No solution found within 15306 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:51:48.568987
# Iteration 1001 finished. Topsoe Divergence H V = 256.2994090080356 Topsoe Divergence H U = 76.19779329958666
# heat_map_alteration execution finished after 0.9474162999995315 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:51:49.882485
# Profile U: new_aysmsla Profile H: new_eegcef belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:51:50.481556
# Iteration 1001 finished. Topsoe Divergence H V = 149.8847313011143 Topsoe Divergence H U = 96.12696456551924
# heat_map_alteration execution finished after 0.9518748999998934 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:51:51.811937
# Iteration 1001 finished. Topsoe Divergence H V = 328.8899631479795 Topsoe Divergence H U = 110.88847648126755
# heat_map_alteration execution finished after 0.9698346999994101 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:51:53.165554
# Iteration 1001 finished. Topsoe Divergence H V = 95.87819871981729 Topsoe Divergence H U = 36.67192044490994
# heat_map_alteration execution finished after 0.9549502999998367 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:51:54.481430
# Profile U: new_otswrank Profile H: new_eesbaj belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:51:54.942467
# Iteration 1072 finished. Topsoe Divergence H V = 82.18506926386793 Topsoe Divergence H U = 82.19742015015474
# heat_map_alteration execution finished after 1.0059085000011692 seconds
# Starting heat_map_alteration at: 2024-07-20 12:51:56.464908
# Profile U: new_ojroigna Profile H: new_effneomi belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:51:56.921032
# Profile U: new_uthomoov Profile H: new_efghakdi belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:51:57.403676
# Iteration 1001 finished. Topsoe Divergence H V = 101.12027611411905 Topsoe Divergence H U = 37.45235617104029
# heat_map_alteration execution finished after 0.9716913000011118 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:51:58.738434
# Iteration 1001 finished. Topsoe Divergence H V = 184.84660723954414 Topsoe Divergence H U = 114.98884225053772
# heat_map_alteration execution finished after 0.9385236999987683 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:52:00.102910
# Profile U: new_inckkiv Profile H: new_efonve belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:52:00.748475
# Profile U: new_evbacclu Profile H: new_efspheco belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:52:01.208474
# Iteration 1001 finished. Topsoe Divergence H V = 182.85465367104806 Topsoe Divergence H U = 63.631323263377105
# heat_map_alteration execution finished after 0.9608600000010483 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:52:02.568091
# Iteration 1026 finished. Topsoe Divergence H V = 120.4995479766685 Topsoe Divergence H U = 120.54758921078538
# heat_map_alteration execution finished after 0.9828023000009125 seconds
# Starting heat_map_alteration at: 2024-07-20 12:52:03.927208
# Iteration 1001 finished. Topsoe Divergence H V = 130.7867001351683 Topsoe Divergence H U = 48.851263420494085
# heat_map_alteration execution finished after 0.9681853000001865 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:52:05.304478
# Profile U: new_atidfi Profile H: new_egnatab belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:52:05.935603
# Iteration 150000 finished. Topsoe Divergence H V = 1251088.9647024567 Topsoe Divergence H U = 1250051.241826224
# heat_map_alteration execution finished after 113.84565839999959 seconds
# Starting heat_map_alteration at: 2024-07-20 12:54:00.205246
# Profile U: new_insodfl Profile H: new_egreosko belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:54:00.735055
# Profile U: new_uthiss Profile H: new_egteir belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:54:01.240794
# Iteration 733 finished. Topsoe Divergence H V = 98.29840252237975 Topsoe Divergence H U = 98.29943424547682
# heat_map_alteration execution finished after 0.7624888000009378 seconds
# Starting heat_map_alteration at: 2024-07-20 12:54:02.386804
# Profile U: new_ackgrica Profile H: new_eiboidne belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:54:02.997844
# Iteration 1001 finished. Topsoe Divergence H V = 116.34807804176948 Topsoe Divergence H U = 52.89825744022938
# heat_map_alteration execution finished after 0.9621449999995093 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:04.386966
# Iteration 2999 finished. Topsoe Divergence H V = 72.06464611616268 Topsoe Divergence H U = 72.06654142546547
# heat_map_alteration execution finished after 2.5036012000000483 seconds
# Starting heat_map_alteration at: 2024-07-20 12:54:07.263992
# Profile U: new_abjoolaw Profile H: new_eincufpy belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:54:07.728888
# Iteration 1001 finished. Topsoe Divergence H V = 411.7707228001808 Topsoe Divergence H U = 87.46256987158245
# heat_map_alteration execution finished after 0.9485172999993665 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:09.053267
# Iteration 1001 finished. Topsoe Divergence H V = 254.8158363919722 Topsoe Divergence H U = 55.163108995376426
# heat_map_alteration execution finished after 0.9456871999991563 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:10.532123
# Iteration 1001 finished. Topsoe Divergence H V = 142.1478936199141 Topsoe Divergence H U = 51.516124822433234
# heat_map_alteration execution finished after 0.97858400000041 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:11.912201
# Iteration 1001 finished. Topsoe Divergence H V = 134.73956044536806 Topsoe Divergence H U = 75.49973095823552
# heat_map_alteration execution finished after 1.029982200001541 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:13.319231
# Iteration 2946 finished. Topsoe Divergence H V = 207.58562453962358 Topsoe Divergence H U = 122.3126980695242
# heat_map_alteration execution finished after 2.4023611000011442 seconds
# No solution found within 2946 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:16.110181
# Iteration 1001 finished. Topsoe Divergence H V = 244.7456423222403 Topsoe Divergence H U = 70.31693052227212
# heat_map_alteration execution finished after 0.9755182999997487 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:17.483955
# Iteration 3378 finished. Topsoe Divergence H V = 82.72209204046578 Topsoe Divergence H U = 74.6059146924533
# heat_map_alteration execution finished after 2.672198299998854 seconds
# No solution found within 3378 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:20.648237
# Iteration 9518 finished. Topsoe Divergence H V = 157.1382416400208 Topsoe Divergence H U = 123.31311135112152
# heat_map_alteration execution finished after 7.56942220000019 seconds
# No solution found within 9518 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:28.594311
# Profile U: new_oafhynu Profile H: new_ekfrab belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:54:29.094938
# Iteration 6845 finished. Topsoe Divergence H V = 100.22918749280137 Topsoe Divergence H U = 100.23345025813174
# heat_map_alteration execution finished after 5.244986300000164 seconds
# Starting heat_map_alteration at: 2024-07-20 12:54:34.714985
# Iteration 1001 finished. Topsoe Divergence H V = 107.90633571244028 Topsoe Divergence H U = 62.69596801293953
# heat_map_alteration execution finished after 0.9921591000002081 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:36.097477
# Profile U: new_ickphiwa Profile H: new_ekyosjo belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:54:36.674477
# Profile U: new_oblyaga Profile H: new_elaflevy belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:54:37.168664
# Iteration 1001 finished. Topsoe Divergence H V = 304.5559068963675 Topsoe Divergence H U = 58.97663817099562
# heat_map_alteration execution finished after 0.9508255000000645 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:38.508106
# Iteration 5618 finished. Topsoe Divergence H V = 400.7497827736526 Topsoe Divergence H U = 400.7522719227917
# heat_map_alteration execution finished after 4.3384296000003815 seconds
# Starting heat_map_alteration at: 2024-07-20 12:54:43.245324
# Profile U: new_owgves Profile H: new_elhuyoi belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:54:43.726633
# Iteration 4187 finished. Topsoe Divergence H V = 107.77504537241045 Topsoe Divergence H U = 85.50856544191626
# heat_map_alteration execution finished after 3.323505100001057 seconds
# No solution found within 4187 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:47.584093
# Iteration 12786 finished. Topsoe Divergence H V = 100.63055396628572 Topsoe Divergence H U = 60.9085440362124
# heat_map_alteration execution finished after 9.915481 seconds
# No solution found within 12786 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:57.844813
# Iteration 1001 finished. Topsoe Divergence H V = 160.33843286242592 Topsoe Divergence H U = 46.99571264966989
# heat_map_alteration execution finished after 0.9356690000004164 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:54:59.151812
# Profile U: new_okblahed Profile H: new_elwesnn belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:54:59.675611
# Iteration 1001 finished. Topsoe Divergence H V = 78.45141255466677 Topsoe Divergence H U = 56.97632342195215
# heat_map_alteration execution finished after 0.9787023000008048 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:55:01.033781
# Profile U: new_ophgir Profile H: new_enekbl belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:55:01.630060
# Iteration 1001 finished. Topsoe Divergence H V = 58.392052375644475 Topsoe Divergence H U = 44.78913876368629
# heat_map_alteration execution finished after 0.9372433000007732 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:55:02.915712
# Iteration 1001 finished. Topsoe Divergence H V = 151.67514567698103 Topsoe Divergence H U = 45.868851335627454
# heat_map_alteration execution finished after 0.994537800001126 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:55:04.271275
# Iteration 1001 finished. Topsoe Divergence H V = 112.12577089759921 Topsoe Divergence H U = 55.43806394269366
# heat_map_alteration execution finished after 0.985262899999725 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:55:05.640288
# Profile U: new_objoyhi Profile H: new_enyenewl belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:55:06.105193
# Profile U: new_eadectio Profile H: new_enyonsn belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:55:06.702195
# Iteration 1001 finished. Topsoe Divergence H V = 158.83458969876884 Topsoe Divergence H U = 60.25348115902748
# heat_map_alteration execution finished after 0.9570386000013968 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:55:08.020783
# Iteration 1001 finished. Topsoe Divergence H V = 147.5733007863941 Topsoe Divergence H U = 42.86381164042134
# heat_map_alteration execution finished after 0.9488791999992827 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:55:09.356084
# Iteration 7517 finished. Topsoe Divergence H V = 191.87419660980996 Topsoe Divergence H U = 105.11556093795144
# heat_map_alteration execution finished after 5.933226999999533 seconds
# No solution found within 7517 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:55:15.649689
# Profile U: new_aldhidd Profile H: new_eokracy belong to a different owner. No need for obfuscation. Returning H.
# Starting heat_map_alteration at: 2024-07-20 12:55:16.125719
# Iteration 1001 finished. Topsoe Divergence H V = 198.83416099338731 Topsoe Divergence H U = 85.09945025092188
# heat_map_alteration execution finished after 0.971594599999662 seconds
# No solution found within 1001 iterations. Returning heat map V as a substitute.
# Starting heat_map_alteration at: 2024-07-20 12:55:17.582818
# Iteration 85177 finished. Topsoe Divergence H V = 133.79271388104485 Topsoe Divergence H U = 133.79306001126818
# heat_map_alteration execution finished after 67.64092719999826 seconds
# Starting heat_map_alteration at: 2024-07-20 12:56:25.591540
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 158
#     155         stop_event.set()  # Set the event to stop the monitor thread
#     157 for seed in random_seeds:
# --> 158     process_data(split_algorithm, scenarios, seed)
#     161 ## Start the memory monitoring in a separate thread
#     162 #monitor_thread = threading.Thread(target=monitor_memory, args=(stop_event,))
#     163 #monitor_thread.daemon = True
#    (...)
#     173 # Ensure the monitor thread is stopped
#     174 #monitor_thread.join()
#
# Cell In[37], line 97, in process_data(split_algorithm, scenarios, seed)
#      95 smallest_distance_name = ""
#      96 obfuscation_factor = max(len(precomputed_profile_data_first[profile_id_baseline].profile_data) / 500, 50)
# ---> 97 obfuscated_baseline, amount_iterations = heat_map_alteration(precomputed_profile_data_first[profile_id_baseline], obfuscation_factor, precomputed_profile_data_last, 1000)
#      99 for _, data_comparee in precomputed_profile_data_last.items():
#     101     topsoe_divergence = calculate_distance_between_points(obfuscated_baseline, data_comparee.heat_map)
#
# Cell In[30], line 88, in heat_map_alteration(profile_h, obfuscation_factor, all_precomputed_profiles, max_count_iterations)
#      85 matrix_h_dash = (1 / amount_data_points_H) * matrix_o
#      87 topsoe_divergence_h_v = calculate_distance_between_points(heat_map_h_dash, heat_map_v)
# ---> 88 topsoe_divergence_h_u = calculate_distance_between_points(heat_map_h_dash, heat_map_u)
#      90 counter_while += 1
#      92 if (topsoe_divergence_h_v - topsoe_divergence_h_u) < diff_previous:
#
# Cell In[17], line 5, in calculate_distance_between_points(array_a, array_b, distance_type, seed)
#       3     return calculate_topsoe_divergence(array_a, array_b)
#       4 elif distance_type == "hausdorff":
# ----> 5     return calculate_hausdorff_distance(array_a, array_b, seed)
#       6 else:
#       7     raise Exception("Missing selection of distance calculation algorithm!")
#
# Cell In[35], line 2, in calculate_hausdorff_distance(array_a, array_b, seed)
#       1 def calculate_hausdorff_distance(array_a, array_b, seed):
# ----> 2     return scipy.spatial.distance.directed_hausdorff(array_a, array_b, seed)[0]
#
# File d:\Users\Chris\Documents\Studium Extended\Semester 1\Forschungsprojekt\Repository\tinkering\.venv\Lib\site-packages\scipy\spatial\distance.py:409, in directed_hausdorff(u, v, seed)
#     406 if u.shape[1] != v.shape[1]:
#     407     raise ValueError('u and v need to have the same '
#     408                      'number of columns')
# --> 409 result = _hausdorff.directed_hausdorff(u, v, seed)
#     410 return result
#
# KeyboardInterrupt:

# %%
### Scenario 2: Execute AP-Attack on the non obfuscated (NOBF) data sets  

"""
Select which data set shall be used
# !! Important: The synthetic_profiles by default DO NOT have a Timestamp component, which means that splits BY DATE are NOT possible !!
"""
# Allowed keywords "SYNTHETIC" or "NORMAL"
scenarios = ["SYNTHETIC", "NORMAL"]
# Allowed keywords "HALF" or "RANDOM" or "CLUSTER"
split_algorithm = ["RANDOM"]

# Seeds generated with https://www.random.org/ True Random Number Generator, Params Min: 1, Max: 10000
random_seeds = [8046, 8251, 8166, 435, 7782, 9807, 3582, 21, 5446, 781]

def process_data(split_algorithm, scenarios, seed):
    for algorithm in split_algorithm:
        for scenario in scenarios:
            try:
                if scenario == "SYNTHETIC":
                    profiles_list_cleansed = remove_profiles_out_of_bounds_coordinates(synthetic_profiles)
                    print("Synthetic data set selected")
                elif scenario == "NORMAL":
                    profiles_list_cleansed = remove_profiles_out_of_bounds_coordinates(profiles_list)
                    print("Normal data set selected")
                else:
                    print(f"No dataset {scenario} could be found!")
                    sys.exit()

                # Select split function
                if algorithm == "HALF":
                    first_50, last_50 = split_data_frame_list_by_half(profiles_list_cleansed)
                elif algorithm == "RANDOM":
                    first_50, last_50 = split_data_frame_list_randomly(profiles_list_cleansed, seed)
                elif algorithm == "CLUSTER":
                    first_50, last_50 = split_data_frame_list_by_cluster(profiles_list)
                else:
                    print(f"No Split Algorithm {algorithm} could be found!")

                first_50 = list(filter(lambda df: not df.empty, first_50))
                last_50 = list(filter(lambda df: not df.empty, last_50))

                output_folder_path = Path('Daten/Ausgabe/AP Scenario NOB 50_50')
                output_folder = src_path / output_folder_path
                os.makedirs(output_folder, exist_ok=True)

                results = []

                i = 1
                j = 1
                for comparee_baseline in first_50:
                    i = 1

                    smallest_distance = np.inf
                    smallest_distance_name = ""
                    heatmap_baseline = create_heatmap(comparee_baseline)

                    for comparee_comparison in last_50:
                        heatmap_comparee = create_heatmap(comparee_comparison)

                        topsoe_divergence = calculate_distance_between_points(heatmap_baseline, heatmap_comparee)

                        if topsoe_divergence < smallest_distance:
                            smallest_distance = topsoe_divergence
                            smallest_distance_name = comparee_comparison["FileName"].iloc[0]

                        #print(f"Iteration: {j}.{i} Topsoe Divergence between {comparee_baseline['FileName'].iloc[0]} and {comparee_comparison['FileName'].iloc[0]}: {topsoe_divergence}")
                        i += 1

                    results.append({'Baseline': comparee_baseline["FileName"].iloc[0], 'Comparee': smallest_distance_name, 'Distance': smallest_distance, "Equal File Name": "Yes" if smallest_distance_name == comparee_baseline["FileName"].iloc[0] else "No"})
                    j += 1

                results_df = pd.DataFrame(results)
                results_df = results_df.sort_values("Distance")

                now = datetime.now()
                formatted_date = now.strftime("%Y%m%d_%H%M%S")

                output_path = os.path.join(output_folder, f"ap_output_NOB_{scenario}_{algorithm}_{formatted_date}_SEED{seed}.csv")
                results_df.to_csv(output_path, index=False)

                # Calculate additional metrics
                final_results_df = pd.read_csv(output_path)
                final_results_df['Row_Count'] = len(final_results_df)
                yes_count = final_results_df['Equal File Name'].value_counts().get('Yes', 0)
                no_count = final_results_df['Equal File Name'].value_counts().get('No', 0)
                total_count = yes_count + no_count
                final_results_df['Total_Yes'] = yes_count
                final_results_df['Total_No'] = no_count
                final_results_df['Percentage_Yes'] = (yes_count / total_count) * 100 if total_count > 0 else 0
                final_results_df['Percentage_No'] = (no_count / total_count) * 100 if total_count > 0 else 0

                final_results_df.to_csv(output_path, index=False)
            finally:
                gc.collect()

for seed in random_seeds:
    print(psutil.virtual_memory().percent)
    process_data(split_algorithm, scenarios, seed)
# Out:
# 47.4
# Synthetic data set selected
# Normal data set selected
# 49.4
# Synthetic data set selected
# Normal data set selected
# 54.3
# Synthetic data set selected
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File d:\Users\Chris\Documents\Studium Extended\Semester 1\Forschungsprojekt\Repository\tinkering\.venv\Lib\site-packages\numpy\lib\histograms.py:969, in histogramdd(sample, bins, range, density, weights)
#     967 try:
#     968     # Sample is an ND-array.
# --> 969     N, D = sample.shape
#     970 except (AttributeError, ValueError):
#     971     # Sample is a sequence of 1D arrays.
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 98
#      96 for seed in random_seeds:
#      97     print(psutil.virtual_memory().percent)
# ---> 98     process_data(split_algorithm, scenarios, seed)
#
# Cell In[36], line 58, in process_data(split_algorithm, scenarios, seed)
#      55 heatmap_baseline = create_heatmap(comparee_baseline)
#      57 for comparee_comparison in last_50:
# ---> 58     heatmap_comparee = create_heatmap(comparee_comparison)
#      60     topsoe_divergence = calculate_distance_between_points(heatmap_baseline, heatmap_comparee)
#      62     if topsoe_divergence < smallest_distance:
#
# Cell In[20], line 27, in create_heatmap(df, lon_bins, lat_bins, density)
#      24 lat_bins = np.linspace(lat_min, lat_max, num_lat_bins)
#      26 # Create 2D histogram
# ---> 27 hist, _, _ = np.histogram2d(lon, lat, bins=[lon_bins, lat_bins], density=density)
#      29 # Replace zero values with a small number to avoid issues with log calculations
#      30 hist[hist == 0] = 1e-10
#
# File d:\Users\Chris\Documents\Studium Extended\Semester 1\Forschungsprojekt\Repository\tinkering\.venv\Lib\site-packages\numpy\lib\twodim_base.py:808, in histogram2d(x, y, bins, range, density, weights)
#     806     xedges = yedges = asarray(bins)
#     807     bins = [xedges, yedges]
# --> 808 hist, edges = histogramdd([x, y], bins, range, density, weights)
#     809 return hist, edges[0], edges[1]
#
# File d:\Users\Chris\Documents\Studium Extended\Semester 1\Forschungsprojekt\Repository\tinkering\.venv\Lib\site-packages\numpy\lib\histograms.py:972, in histogramdd(sample, bins, range, density, weights)
#     969     N, D = sample.shape
#     970 except (AttributeError, ValueError):
#     971     # Sample is a sequence of 1D arrays.
# --> 972     sample = np.atleast_2d(sample).T
#     973     N, D = sample.shape
#     975 nbin = np.empty(D, np.intp)
#
# File d:\Users\Chris\Documents\Studium Extended\Semester 1\Forschungsprojekt\Repository\tinkering\.venv\Lib\site-packages\numpy\core\shape_base.py:121, in atleast_2d(*arys)
#     119 res = []
#     120 for ary in arys:
# --> 121     ary = asanyarray(ary)
#     122     if ary.ndim == 0:
#     123         result = ary.reshape(1, 1)
#
# KeyboardInterrupt:

# %%
def fill_mobility_of_cell(list_of_all_available_time_gaps, set_of_mobility_traces_to_copy_from, max_speed_between_time_gaps, max_time_gap_inside_set_of_records, limit_duration_of_data_points_to_copy):
    
    """
    TODO: Complete function for mobility trace reconstruction. Check paper for rererence. 
    """
    # Filter list_of_all_available_time_gaps to fulfill being in cell i, j & are within max_speed_between_time_gaps

    # Split set_of_mobility_traces_to_copy_from by max_time_gap_inside_set_of_records

    # Select element from list_of_all_available_time_gaps & set_of_mobility_traces_to_copy_from with least distance. Distance is the sum of the distance\
    # from start of the gap to the set of records AND from the set of records to the ending point of the gap
    None

# %%
def mobility_trace_reconstruction(obfuscated_heat_map, original_mobility_trace):

    """
    TODO: Complete function for mobility trace reconstruction. Check paper for rererence. 
    """

    modified_mobility_trace = modify_number_of_records(original_mobility_trace, len(obfuscated_heat_map))
    #modify_number_of_records(original_mobility_trace, amount_target_datapoints)
    #print(modified_mobility_trace)


profiles_list_cleansed = remove_profiles_out_of_bounds_coordinates(profiles_list)
#print(f"Amount of profiles before: {len(profiles_list)} Amount of profiles after: {len(profiles_list_cleansed)}")

first_80, last_20 = split_data_frame_list_by_half(profiles_list_cleansed)

first_80 = list(filter(lambda df: not df.empty, first_80))
last_20 = list(filter(lambda df: not df.empty, last_20))

profile_to_obfuscate = last_20[1]
#print(ele[:10])

obfuscated_heat_map = heat_map_alteration(profile_to_obfuscate, 100, first_80[:50], 1000) #heat_map_alteration(profiles_list[4], 0.5, profiles_list[5:100], len(profiles_list[4]), 10000)
    
results = mobility_trace_reconstruction(obfuscated_heat_map, profile_to_obfuscate)
#print(results)
